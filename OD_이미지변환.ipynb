# %%
import os

# %%
os.getcwd()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
class_list = os.listdir('/content/drive/MyDrive/Detection_Test/tiff_jpg/')

class_dir = '/content/drive/MyDrive/Detection_Test/tiff_jpg/'

# %%
class_list

# %%
class_dir + class_list[1]

# %%
con_dir = class_dir + class_list[1]

# %%
con_list = os.listdir(class_dir + class_list[1])

# %%
con_dir + '/'+ con_list[1]

# %%
class_list[0]

# %%
import os 
os.getcwd()

# %%
class_dir+class_list[1]

# %%
os.listdir(class_dir+class_list[0])

# %%
from PIL import Image

# %%
for i in range(len(class_list)):
    con_dir = class_dir + class_list[i]
    #print(con_dir)
    subclass = os.listdir(con_dir)
    for k in range(len(subclass)):
        subclass_dir = con_dir +'/'+ subclass[k]
        #print(subclass_dir)
        image = os.listdir(subclass_dir)
        for j in range(len(image)):
            image_dir = subclass_dir+'/'+image[j]
            outfile = image[j][:-4] + 'jpg'
            im = Image.open(image_dir)
            conv = im.convert("RGB")
            conv.save(subclass_dir+'/'+outfile,"JPEG",quality=90)

# %%
image_dir

# %%
subclass_dir+'/'+outfile

# %%
# 이건 연습

for i in range(len(class_list)):
    for f in os.listdir(class_dir+class_list[i]):
        #print(f)
        if f[-4:] == "tiff" :
        # print "is tif or bmp"
            outfile = f[:-4] + "jpg"
            # im = Image.open(class_dir+class_list[i]+'/'+ f)
            # print ("new filename : " + outfile)
            # out = im.convert("RGB")
            # out.save(class_dir+class_list[i]+'/'+ outfile, "JPEG", quality=90)
            print(outfile)

# %%
# 이건 연습

for i in range(len(class_list)):
    for f in os.listdir(b[i]):
        #print(f)
        if f[-4:] == "tiff" :
        # print "is tif or bmp"
            outfile = f[:-4] + "jpg"
            im = Image.open(b[i]+'/'+ f)
            print ("new filename : " + outfile)
            out = im.convert("RGB")
            out.save(class_dir+class_list[i]+'/'+ outfile, "JPEG", quality=90)
